# %%
import os

os.listdir("../data")
# Out:
# ['clean_output.csv', 'netflix_clean.csv', 'netflix_titles.csv']

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/clean_output.csv")

df.head()
# Out:
#   show_id     type                                  title        director  \
# 0    s694    Movie                 Ali & Ratu Ratu Queens  Lucky Kuswandi
# 1    s782    Movie  Black Holes | The Edge of All We Know   Peter Galison
# 2    s763    Movie                           Sweet & Sour   Lee Kae-byeok
# 3    s764  TV Show                            Sweet Tooth         Unknown
# 4    s765    Movie           Trippin' with the Kandasamys   Jayan Moodley
#
#                                                 cast        country  \
# 0  Iqbaal Ramadhan, Nirina Zubir, Asri Welas, Tik...        Unknown
# 1                                            Unknown        Unknown
# 2          Jang Ki-yong, Chae Soo-bin, Jung Soo-jung    South Korea
# 3  Nonso Anozie, Christian Convery, Adeel Akhtar,...  United States
# 4  Jailoshini Naidoo, Maeshni Naicker, Madhushan ...   South Africa
#
#    date_added  release_year rating  duration  \
# 0  2021-06-17          2021  TV-14   101 min
# ...

# %%
import os

print(os.getcwd())
# Out:
# /Users/shubhigupta/Downloads/netflix-analysis-project/notebooks

# %%
sns.boxplot(
    x=df["release_year"]
)

plt.show()

# %% [markdown]
# This boxplot helps identify unusually old or unusual release years.

# %%
sns.heatmap(
    numeric_df.corr(),
    annot=True
)

plt.show()

# %%
numeric_df = df[["release_year","content_age"]]

numeric_df.corr()
# Out:
#               release_year  content_age
# release_year           1.0         -1.0
# content_age           -1.0          1.0

# %%
##This histogram shows how Netflix content is distributed across release years.

# %%
sns.histplot(df["release_year"])

plt.show()

# %%
df.describe()
# Out:
#        release_year  content_age
# count   8807.000000  8807.000000
# mean    2014.180198    11.819802
# std        8.819312     8.819312
# min     1925.000000     5.000000
# 25%     2013.000000     7.000000
# 50%     2017.000000     9.000000
# 75%     2019.000000    13.000000
# max     2021.000000   101.000000

# %%
type_counts = df["type"].value_counts()

sns.barplot(
    x=type_counts.index,
    y=type_counts.values
)

plt.title("Movies vs TV Shows")
plt.show()

# %%
rating_counts = df["rating"].value_counts().head(10)

sns.barplot(
    x=rating_counts.values,
    y=rating_counts.index
)

plt.title("Top Ratings")

plt.show()

# %%
year_counts = df["release_year"].value_counts().sort_index()

plt.figure(figsize=(10,5))

plt.plot(
    year_counts.index,
    year_counts.values
)

plt.title("Netflix Content by Release Year")

plt.show()

# %%
## Movies vs TV Shows This chart shows the number of Movies and TV Shows available on Netflix.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("../data/clean_output.csv")

df.head()
# Out:
#   show_id     type                                  title        director  \
# 0    s694    Movie                 Ali & Ratu Ratu Queens  Lucky Kuswandi
# 1    s782    Movie  Black Holes | The Edge of All We Know   Peter Galison
# 2    s763    Movie                           Sweet & Sour   Lee Kae-byeok
# 3    s764  TV Show                            Sweet Tooth         Unknown
# 4    s765    Movie           Trippin' with the Kandasamys   Jayan Moodley
#
#                                                 cast        country  \
# 0  Iqbaal Ramadhan, Nirina Zubir, Asri Welas, Tik...        Unknown
# 1                                            Unknown        Unknown
# 2          Jang Ki-yong, Chae Soo-bin, Jung Soo-jung    South Korea
# 3  Nonso Anozie, Christian Convery, Adeel Akhtar,...  United States
# 4  Jailoshini Naidoo, Maeshni Naicker, Madhushan ...   South Africa
#
#    date_added  release_year rating  duration  \
# 0  2021-06-17          2021  TV-14   101 min
# ...

# %%
import os

os.listdir("../data")
# Out:
# ['clean_output.csv', 'netflix_clean.csv', 'netflix_titles.csv']
